# %%
# !pip uninstall vertexai
# Out:
# Found existing installation: vertexai 0.0.1
# Uninstalling vertexai-0.0.1:
#   Would remove:
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/*
#   Would not remove (might be manually added):
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Babel-2.11.0.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Brotli-1.1.0.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/LICENSE.rst
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Deprecated-1.2.13.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/AUTHORS
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/GitPython-3.1.37.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/__main__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/conftest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/consoleapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/alias.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/application.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/async_helpers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/autocall.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/builtin_trap.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/compilerop.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/completer.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/completerlib.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/crashhandler.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/debugger.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/display_functions.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/display_trap.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/displayhook.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/displaypub.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/error.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/events.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/excolors.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/extensions.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/formatters.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/getipython.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/guarded_eval.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/history.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/historyapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/hooks.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/inputsplitter.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/inputtransformer.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/inputtransformer2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/latex_symbols.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/logger.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/macro.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magic_arguments.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/ast_mod.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/auto.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/basic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/code.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/config.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/execution.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/extension.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/history.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/logging.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/namespace.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/osm.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/packaging.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/pylab.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/magics/script.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/oinspect.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/page.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/payload.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/payloadpage.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/prefilter.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/profile/README_STARTUP
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/profileapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/profiledir.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/prompts.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/pylabtools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/release.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/shellapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/splitinput.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/2x2.jpg
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/2x2.png
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/bad_all.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/daft_extension/daft_extension.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/nonascii.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/nonascii2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/print_argv.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/refbug.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/simpleerr.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/tclass.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_alias.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_application.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_async_helpers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_autocall.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_compilerop.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_completer.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_completerlib.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_debugger.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_displayhook.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_events.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_exceptiongroup_tb.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_extension.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_formatters.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_guarded_eval.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_handlers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_history.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_hooks.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_imports.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_inputsplitter.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_inputtransformer.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_inputtransformer2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_inputtransformer2_line.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_interactiveshell.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_iplib.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_logger.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_magic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_magic_arguments.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_magic_terminal.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_oinspect.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_page.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_paths.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_prefilter.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_profile.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_prompts.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_pylabtools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_run.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_shellapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_splitinput.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/tests/test_ultratb.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/ultratb.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/usage.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/autoreload.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/storemagic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/tests/test_autoreload.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/extensions/tests/test_storemagic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/external/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/external/qt_for_kernel.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/external/qt_loaders.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/external/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/external/tests/test_qt_loaders.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/backgroundjobs.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/clipboard.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/deepreload.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/demo.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/editorhooks.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/guisupport.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/latextools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/lexers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/pretty.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test.wav
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_backgroundjobs.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_clipboard.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_deepreload.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_display.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_editorhooks.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_imports.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_latextools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_lexers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_pretty.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/lib/tests/test_pygments.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/paths.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/py.typed
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/sphinxext/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/sphinxext/custom_doctests.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/sphinxext/ipython_console_highlighting.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/sphinxext/ipython_directive.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/console.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/debugger.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/embed.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/interactiveshell.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/ipapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/magics.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/prompts.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/asyncio.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/glut.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/gtk.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/gtk3.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/gtk4.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/osx.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/pyglet.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/qt.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/tk.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/wx.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/ptutils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/shortcuts/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/shortcuts/auto_match.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/shortcuts/auto_suggest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/shortcuts/filters.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_debug_magic.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_embed.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_help.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_interactivshell.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_pt_inputhooks.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/terminal/tests/test_shortcuts.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/decorators.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/globalipapp.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/ipunittest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/README.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/dtexample.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/ipdoctest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/pytest_ipdoctest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/setup.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/simple.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/simplevars.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/test_combo.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/test_example.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/test_exampleip.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/test_ipdoctest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/plugin/test_refs.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/skipdoctest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/tests/test_decorators.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/tests/test_ipunittest.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/tests/test_tools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/testing/tools.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/PyColorize.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_process_cli.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_process_common.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_process_posix.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_process_win32.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_process_win32_controller.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/_sysinfo.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/capture.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/colorable.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/coloransi.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/contexts.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/daemonize.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/data.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/decorators.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/dir2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/docs.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/encoding.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/eventful.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/frame.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/generics.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/importstring.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/io.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/ipstruct.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/jsonutil.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/localinterfaces.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/log.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/module_paths.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/openpy.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/path.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/process.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/py3compat.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/sentinel.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/shimmodule.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/signatures.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/strdispatch.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/sysinfo.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/syspathcontext.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tempdir.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/terminal.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_capture.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_decorators.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_deprecated.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_dir2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_imports.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_importstring.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_io.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_module_paths.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_openpy.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_path.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_process.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_pycolorize.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_shimmodule.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_sysinfo.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_tempdir.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_text.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_tokenutil.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tests/test_wildcard.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/text.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/timing.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tokenutil.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/traitlets.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/tz.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/ulinecache.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/version.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/utils/wildcard.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/LICENSE.rst
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Jinja2-3.1.2.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/LICENSE.md
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Markdown-3.5.2.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/LICENSE.rst
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/MarkupSafe-2.1.4.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/SSL.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/_util.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/crypto.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/debug.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/rand.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/OpenSSL/version.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/AUTHORS.rst
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyJWT-2.8.0.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PySocks-1.7.1.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/AUTHORS
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Pygments-2.15.1.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/README.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Send2Trash-1.8.2.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/INSTALLER
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/LICENSE
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/METADATA
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/RECORD
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/REQUESTED
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/WHEEL
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/direct_url.json
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/entry_points.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/Unidecode-1.2.0.dist-info/top_level.txt
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_argon2_cffi_bindings/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_argon2_cffi_bindings/_ffi.abi3.so
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_argon2_cffi_bindings/_ffi_build.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_brotli.cpython-310-darwin.so
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_cffi_backend.cpython-310-darwin.so
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_distutils_hack/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_distutils_hack/override.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/_yaml/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/app.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/app.pyi
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/command_name.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_argument_parser.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_defines.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_exceptions.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_flag.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_flagvalues.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_helpers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_validators.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/_validators_classes.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/absl/flags/argparse_flags.py
# ...
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/partial_batch_padding_handler.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/saving.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/sequential.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_arrays_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_distributed_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_eager_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_generator_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_utils_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/engine/training_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/initializers/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/initializers/initializers_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/initializers/initializers_v2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/keras_parameterized.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/advanced_activations.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/convolutional.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/convolutional_recurrent.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/core.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/dense_attention.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/embeddings.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/legacy_rnn/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_wrapper_impl.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/merge.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/pooling.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/recurrent.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/rnn_cell_wrapper_v2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/layers/serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/base.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/convolutional.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/pooling.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/legacy_tf_layers/variable_scope_shim.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/losses.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/metrics.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/autocast_variable.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/device_compatibility_check.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/get_layer_policy.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/loss_scale.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/loss_scale_optimizer.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/policy.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/mixed_precision/test_util.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/models.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v1.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/adadelta.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/adagrad.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/adam.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/adamax.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/ftrl.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/gradient_descent.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/learning_rate_schedule.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/legacy_learning_rate_decay.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/nadam.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/rmsprop.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizer_v2/utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/optimizers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/protobuf/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/protobuf/projector_config_pb2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/protobuf/saved_metadata_pb2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/protobuf/versions_pb2.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/regularizers.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/hdf5_format.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/model_config.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/save.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/base_serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/constants.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/json_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/layer_serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/load.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/load_context.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/metric_serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/model_serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/network_serialization.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/save.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/save_impl.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/serialized_attributes.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model/utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saved_model_experimental.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/saving_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/export_output.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/export_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/mode_keys.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/signature_def_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/saving/utils_v1/unexported_constants.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/testing_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/all_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/control_flow_util.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/conv_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/data_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/dataset_creator.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/generic_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/io_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/kernelized_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/layer_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/losses_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/metrics_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/mode_keys.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/np_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/object_identity.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/tf_contextlib.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/tf_inspect.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/tf_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/version_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/keras/utils/vis_utils.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/kernel_tests/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/kernel_tests/nn_ops/__init__.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/kernel_tests/nn_ops/bias_op_base.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/kernel_tests/nn_ops/cudnn_deterministic_base.py
#     /Users/n.c.rodriguez/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/kernel_tests/nn_ops/depthwise_conv_op_base.py
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ^C
# ERROR: Operation cancelled by user

# %%
# !pip install vertexai
# Out:
# Collecting vertexai
#   Downloading vertexai-0.0.1-py3-none-any.whl.metadata (615 bytes)
# Using cached vertexai-0.0.1-py3-none-any.whl (6.0 kB)
# Installing collected packages: vertexai
# Successfully installed vertexai-0.0.1

# %%
import vertexai

# %%
import numpy as np
from vertexai.language_models import TextEmbeddingModel

# %%
in_1 = "Hemos observado un ibis volando hacia la laguna"

in_2 = "Avistada una nutria en la costa"

in_3 = "Un perro parece divertirse con los delfines"


in_4 = "La ensalada de aguacate está deliciosa!"

in_5 = "Me encanta la comida japonesa!"


in_6 = "Los programadores de Python son gente genial"

in_7 = "TypeScript, C++ o Java? Todos molan!"


input_text_lst_news = [in_1, in_2, in_3, in_4, in_5, in_6, in_7]

# %%
embedding_model = TextEmbeddingModel.from_pretrained(
    "textembedding-gecko-multilingual@001")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/cloud/aiplatform/initializer.py:284, in _Config.project(self)
#     283 try:
# --> 284     self._set_project_as_env_var_or_google_auth_default()
#     285     project_id = self._project
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/cloud/aiplatform/initializer.py:90, in _Config._set_project_as_env_var_or_google_auth_default(self)
#      89 else:
# ---> 90     credentials, project = google.auth.default()
#      91     self._credentials = self._credentials or credentials
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/auth/_default.py:692, in default(scopes, request, quota_project_id, default_scopes)
#     690         return credentials, effective_project_id
# --> 692 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/vertexai/_model_garden/_model_garden_models.py:335, in _ModelGardenModel.from_pretrained(cls, model_name)
#     334 try:
# --> 335     return _from_pretrained(interface_class=cls, model_name=model_name)
#     336 except auth_exceptions.GoogleAuthError as e:
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/vertexai/_model_garden/_model_garden_models.py:223, in _from_pretrained(interface_class, model_name, publisher_model, tuned_vertex_model)
#     219         raise ValueError(
#     220             f"Class {interface_class} is not a correct model interface class since it does not have an instance schema URI."
#     221         )
# --> 223     model_info = _get_model_info(
#     224         model_id=model_name,
#     225         schema_to_class_map={interface_class._INSTANCE_SCHEMA_URI: interface_class},
#     226     )
#     228 else:
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/vertexai/_model_garden/_model_garden_models.py:139, in _get_model_info(model_id, schema_to_class_map, interface_class, publisher_model_res, tuned_vertex_model)
#     137 if not publisher_model_res:
#     138     publisher_model_res = (
# --> 139         _publisher_models._PublisherModel(  # pylint: disable=protected-access
#     140             resource_name=model_id
#     141         )._gca_resource
#     142     )
#     144 if not publisher_model_res.name.startswith("publishers/google/models/"):
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/cloud/aiplatform/_publisher_models.py:63, in _PublisherModel.__init__(self, resource_name, project, location, credentials)
#      44 """Retrieves an existing PublisherModel resource given a resource name or model garden id.
#      45
#      46 Args:
#    (...)
#      60         Overrides credentials set in aiplatform.init.
#      61 """
# ---> 63 super().__init__(project=project, location=location, credentials=credentials)
#      65 if self._parse_resource_name(resource_name):
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:510, in VertexAiResourceNoun.__init__(self, project, location, credentials, resource_name)
#     506     project, location = self._get_and_validate_project_location(
#     507         resource_name=resource_name, project=project, location=location
#     508     )
# --> 510 self.project = project or initializer.global_config.project
#     511 self.location = location or initializer.global_config.location
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/google/cloud/aiplatform/initializer.py:287, in _Config.project(self)
#     286 except GoogleAuthError as exc:
# --> 287     raise GoogleAuthError(project_not_found_exception_str) from exc
#     289 if not project_id:
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 embedding_model = TextEmbeddingModel.from_pretrained(
#       2     "textembedding-gecko-multilingual@001")
#
# File ~/anaconda3/envs/nico/lib/python3.10/site-packages/vertexai/_model_garden/_model_garden_models.py:337, in _ModelGardenModel.from_pretrained(cls, model_name)
#     335     return _from_pretrained(interface_class=cls, model_name=model_name)
#     336 except auth_exceptions.GoogleAuthError as e:
# --> 337     raise auth_exceptions.GoogleAuthError(credential_exception_str) from e
#
# GoogleAuthError:
# Unable to authenticate your request.
# Depending on your runtime environment, you can complete authentication by:
# - if in local JupyterLab instance: `!gcloud auth login`
# - if in Colab:
#     -`from google.colab import auth`
#     -`auth.authenticate_user()`
# - if in service account or other: please follow guidance in https://cloud.google.com/docs/authentication

# %% [markdown]
# - Obtenemos embeddings para todas las piezas de texto.
# - Las almacenamos en un array NumPy 2D (una fila por cada embedding).

# %%
embeddings = []
for input_text in input_text_lst_news:
    emb = embedding_model.get_embeddings(
        [input_text])[0].values
    embeddings.append(emb)

embeddings_array = np.array(embeddings)

# %%
print("Shape: " + str(embeddings_array.shape))
print(embeddings_array)

# %% [markdown]
# #### Reducimos embeddings de 768 a 2 dimensiones para visualización
# - Usamos Análisis de Componente Principal (PCA).

# %%
from sklearn.decomposition import PCA

# PCA para visualiz. 2D
PCA_model = PCA(n_components = 2)
PCA_model.fit(embeddings_array)
new_values = PCA_model.transform(embeddings_array)

# %%
print("Shape: " + str(new_values.shape))
print(new_values)

# %%
import matplotlib.pyplot as plt
import mplcursors


def plot_2D(x_values, y_values, labels):

    # Creamos scatter plot
    fig, ax = plt.subplots()
    scatter = ax.scatter(x_values,
                         y_values,
                         alpha = 0.5,
                         edgecolors='k',
                         s = 40)

    # Creamos a mplcursors object to manage the data point interaction
    cursor = mplcursors.cursor(scatter, hover=True)

    #aes
    ax.set_title('Visulaizacion del embedding en 2D')
    ax.set_xlabel('X_1')  # Add x-axis label
    ax.set_ylabel('X_2')  # Add y-axis label

    # Define how each annotation should look
    @cursor.connect("add")
    def on_add(sel):
        sel.annotation.set_text(labels[sel.target.index])
        sel.annotation.get_bbox_patch().set(facecolor='white', alpha=0.5) # Set annotation's background color
        sel.annotation.set_fontsize(12)

    plt.show()


plot_2D(new_values[:,0], new_values[:,1], input_text_lst_news)

# %% [markdown]
# #### Embeddings and Similarity
# - Plot a heat map to compare the embeddings of sentences that are similar and sentences that are dissimilar.

# %%
in_1 = """La cebra come de la planta."""

in_2 = """En la planta surgió un llama"""

in_3 = """Las bacterias pueden aguantar periodos largos de falta de agua."""

in_4 = """Algunos microorganismos son resistentes
          a la escasez de agua."""

input_text_lst_sim = [in_1, in_2, in_3, in_4]

# %%
embeddings = []
for input_text in input_text_lst_sim:
    emb = embedding_model.get_embeddings([input_text])[0].values
    embeddings.append(emb)

embeddings_array = np.array(embeddings)

# %%
def plot_heatmap(data, x_labels=None, y_labels=None, title=None):
    fig, ax = plt.subplots(figsize=(50, 3))
    heatmap = ax.pcolor(data, cmap='coolwarm', edgecolors='k', linewidths=0.1)

    # Add color bar to the right of the heatmap
    cbar = plt.colorbar(heatmap, ax=ax)
    cbar.remove()

    # Set labels for each axis
    if x_labels:
        ax.set_xticks(np.arange(data.shape[1]) + 0.5, minor=False)
        ax.set_xticklabels(x_labels, rotation=45, ha="right")
    if y_labels:
        ax.set_yticks(np.arange(data.shape[0]) + 0.5, minor=False)
        ax.set_yticklabels(y_labels, va="center")

    # Set title
    if title:
        ax.set_title(title)

    plt.tight_layout()

    # Show the plot
    plt.show()


y_labels = input_text_lst_sim

# Plot the heatmap
plot_heatmap(embeddings_array, y_labels = y_labels, title = "Embeddings Heatmap")

# %% [markdown]
# #### Compute cosine similarity
# Esperamos un array 2D en coseno similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def compare(embeddings,idx1,idx2):
    return cosine_similarity([embeddings[idx1]],[embeddings[idx2]])

# %%
print(in_1)
print(in_2)
print(compare(embeddings,0,1))

# %%
print(in_3)
print(in_4)
print(compare(embeddings,2,3))
